# %% [markdown]
# # Preparation

# %% [markdown]
# Preparation biasa dilakukan untuk mempersiapkan data sebelum masuk dalam tahap pemodelan. <br>
# Berikut adalah tahapan yang akan dilalui pada data `SC_HW1_bank_data.csv` sebelum tahap pemodelan :
# 1. Import Library
# 2. Input Dataset
# 3. Preprocessing
# 4. Train-Test Split

# %% [markdown]
# ## Import Library

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Input Dataset

# %%
#Membaca data dan memasukkannya ke dalam bentuk Pandas Dataframe
df = pd.read_csv('https://raw.githubusercontent.com/Rietaros/kampus_merdeka/main/SC_HW1_bank_data.csv')

# %%
#Jalankan code untuk mengecek nama kolom yang tersedia
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Geography', 'Gender', 'Age', 'Tenure',
#        'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
#        'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
#Hilangkan kolom yang dirasa tidak relevan dengan model (contoh: ID). None dapat diisi dengan nama-nama kolom yang akan digunakan.
#Contoh df = df[['X1','X2', 'Y']].copy()

#START CODE
# Pilih kolom-kolom yang relevan
df = df[['Age', 'Balance', 'NumOfProducts', 'IsActiveMember', 'Exited']].copy()

# %% [markdown]
# ## Preprocessing

# %%
#Lakukan One-Hot Encoder untuk data categorical, dengan fungsi pandas get_dummies

#START CODE
categorical_columns = ['Age', 'Balance', 'NumOfProducts', 'IsActiveMember', 'Exited']
df = pd.get_dummies(df, columns=categorical_columns)

# %%
#Pisahkan mana X (feature) dengan Y,
#Y adalah kolom "Exited"

#START CODE
# Memisahkan kolom target (Y) berdasarkan kolom yang sesuai
Y = df[['Exited_1']]
# Menghapus kolom target dari DataFrame untuk mendapatkan fitur (X)
X = df.drop(columns=['Exited_1'])

# %%
#Lakukan Scaler dan/atau Normalisasi jika diperlukan
from sklearn.preprocessing import MinMaxScaler

#START CODE
scaler = MinMaxScaler()
X_transform = scaler.fit_transform(X)

# %%
#Ini digunakan jika dilakukan scaler/Normalisas. Jika tidak, code ini bisa dilewat dan diganti dengan code yang ada di dalam komen
X_transform = pd.DataFrame(X_transform, columns = X.columns)
#X_transform = X.copy()

# %% [markdown]
# ## Train-Test Split

# %%
#Split menjadi train dan test dengan test_size 25%
#Tidak perlu mengubah code ini

from sklearn.model_selection import train_test_split

# Split data menjadi train dan test
X_train, X_test, y_train, y_test = train_test_split(X_transform, Y, test_size=0.25, random_state=123)

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Model1

# %% [markdown]
# ### Soal :
# Jelaskan secara Singkat Model pertama yang digunakan!

# %%
#Pilih salah satu metode Machine Leaarning
#Model Machine Learning dapat dipanggil terlebih dahulu melalui library yang digunakan. Gunakan library scikit learn seperti pada contoh

#Contoh pemanggilan library dan penggunaannya dalam model

#from sklearn.linear_model import LogisticRegression
#model1 = LogisticRegression()
#params = { "tol": [0.1,0.01,0.001], 'C':[0.5,1.0,1.5,2.0]}


#START CODE
from sklearn.linear_model import LogisticRegression
model1 = LogisticRegression()
params = { "tol": [0.1,0.01,0.001], 'C':[0.5,1.0,1.5,2.0]}
#END CODE

#Lakukan parameter tuning sesuai hyperparameter yang dibutuhkan
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(
             estimator= model1,
             param_grid= params,
             scoring = 'accuracy',
             n_jobs = 10, # core cpu yang digunakan
             cv = 10 # 3-fold cross validation (artinya kita melakukan iterasi model sebanyak 3 kali)
            )

grid.fit(X_train,y_train)
grid.best_params_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# {'C': 0.5, 'tol': 0.1}

# %%
#lakukan evaluasi dengan beberapa maetric di bawah ini
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

y_pred = grid.predict(X_test)

print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("Accuracy Score:", accuracy_score(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1983
#            1       1.00      1.00      1.00       517
#
#     accuracy                           1.00      2500
#    macro avg       1.00      1.00      1.00      2500
# weighted avg       1.00      1.00      1.00      2500
#
# Confusion Matrix:
# [[1983    0]
#  [   0  517]]
# Accuracy Score: 1.0

# %% [markdown]
# ## Model2
# ### Soal :
# Jelaskan secara Singkat Model ke-2 yang digunakan!

# %%
#Pilih salah satu metode Machine Leaarning
#Model Machine Learning dapat dipanggil terlebih dahulu melalui library yang digunakan. Gunakan library scikit learn seperti pada contoh

#Contoh pemanggilan library dan penggunaannya dalam model

#from sklearn.linear_model import LogisticRegression
#model1 = LogisticRegression()
#params = { "tol": [0.1,0.01,0.001], 'C':[0.5,1.0,1.5,2.0]}


#START CODE
from sklearn.tree import DecisionTreeClassifier
# Inisialisasi model
model2 = DecisionTreeClassifier()

# Parameter tuning dengan GridSearchCV
params = {
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}
#END CODE

#Lakukan parameter tuning sesuai hyperparameter yang dibutuhkan
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(
             estimator= model2,
             param_grid= params,
             scoring = 'accuracy',
             n_jobs = 10, # core cpu yang digunakan
             cv = 10 # 3-fold cross validation (artinya kita melakukan iterasi model sebanyak 3 kali)
            )

grid.fit(X_train,y_train)
grid.best_params_
# Out:
# {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2}

# %%
#lakukan evaluasi
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

y_pred = grid.predict(X_test)

print("Decision Tree Model:")
print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("Accuracy Score:", accuracy_score(y_test, y_pred))
# Out:
# Decision Tree Model:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1983
#            1       1.00      1.00      1.00       517
#
#     accuracy                           1.00      2500
#    macro avg       1.00      1.00      1.00      2500
# weighted avg       1.00      1.00      1.00      2500
#
# Confusion Matrix:
# [[1983    0]
#  [   0  517]]
# Accuracy Score: 1.0

# %% [markdown]
# ## Model3
# ### Soal :
# Jelaskan secara Singkat Model ke-3 yang digunakan!

# %%
#Pilih salah satu metode Machine Leaarning
#Model Machine Learning dapat dipanggil terlebih dahulu melalui library yang digunakan. Gunakan library scikit learn seperti pada contoh

#Contoh pemanggilan library dan penggunaannya dalam model

#from sklearn.linear_model import LogisticRegression
#model1 = LogisticRegression()
#params = { "tol": [0.1,0.01,0.001], 'C':[0.5,1.0,1.5,2.0]}


#START CODE
from sklearn.ensemble import RandomForestClassifier
# Inisialisasi model
model3 = RandomForestClassifier()

# Parameter tuning dengan GridSearchCV
params = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}
#END CODE

#Lakukan parameter tuning sesuai hyperparameter yang dibutuhkan
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(
             estimator= model3,
             param_grid= params,
             scoring = 'accuracy',
             n_jobs = 10, # core cpu yang digunakan
             cv = 10 # 3-fold cross validation (artinya kita melakukan iterasi model sebanyak 3 kali)
            )

grid.fit(X_train,y_train)
grid.best_params_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:909: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# {'max_depth': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 100}

# %%
#lakukan evaluasi
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

y_pred = grid.predict(X_test)

print("Random Forest Model:")
print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("Accuracy Score:", accuracy_score(y_test, y_pred))
# Out:
# Random Forest Model:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1983
#            1       1.00      1.00      1.00       517
#
#     accuracy                           1.00      2500
#    macro avg       1.00      1.00      1.00      2500
# weighted avg       1.00      1.00      1.00      2500
#
# Confusion Matrix:
# [[1983    0]
#  [   0  517]]
# Accuracy Score: 1.0

# %% [markdown]
# ## Tarik Kesimpulan Model Mana yang terbaik beserta alasannya

# %%
# Kesimpulan dari Model Machine Learning yg digunakan (logistik regression, Decision Tree, Random forest)
# bisa kita lihat bahwa output yang dihasilkan dari semua model yang digunakan menghasilkan score yang sama dengan menggunakan akselerator hardware GPU
# namun dari ketiga model tersebut pada prakteknya membutuhkan waktu yang berbeda saat proses eksekusinya
# Logistic Regression mengeksekusi output lebih cepat.
# Pada dataset yang besar, jika masalahnya memiliki kecenderungan linear yang kuat, Logistic Regression bisa cukup baik dalam melakukan klasifikasi.
# jadi kesimpulannya adalah Logistic Regression lebih baik dibandingkan model lainnya.
